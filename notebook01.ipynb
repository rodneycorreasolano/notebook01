# %%
"" "

importar  numpy  como  np 
importar  matplotlib.pyplot  como  plt


font  =  { 'family' :  'serif' , 
        'color' :   'darkred' , 
        'weight' :  'normal' , 
        'size' :  16 , 
        }

x  =  np . linspace ( 0.0 ,  5.0 ,  100 ) 
y  =  np . cos ( 2 * np . pi * x )  *  np . exp ( - x )

plt . plot ( x ,  y ,  'k' ) 
plt . title ( 'Disminución exponencial amortiguada' ,  fontdict = font ) 
plt . text ( 2 ,  0.65 ,  r '$ \ cos (2 \ pi t) \ exp (-t) $' ,  fontdict = font ) 
plt . xlabel ( 'tiempo (s)' ,  fontdict = font ) 
plt . ylabel ( 'voltaje (mV)' , fontdict = font )

# Ajustar el espaciado para evitar el recorte de la etiqueta 
plab . subplots_adjust ( izquierda = 0.15 ) 
plt . show ()
# Out:
#   File "<ipython-input-1-a48732a384d0>", line 1
#     "" "
#         ^
# SyntaxError: EOL while scanning string literal

# %%
"" " 
=============================================== ======== 
Estilo de control de texto y etiquetas usando un diccionario 
================================= ======================

Este ejemplo muestra cómo compartir parámetros entre muchos objetos de texto y etiquetas 
mediante la creación de un diccionario de opciones transmitidas a través de varias funciones. 
"" "

importar  numpy  como  np 
importar  matplotlib.pyplot  como  plt


font  =  { 'family' :  'serif' , 
        'color' :   'darkred' , 
        'weight' :  'normal' , 
        'size' :  16 , 
        }

x  =  np . linspace ( 0.0 ,  5.0 ,  100 ) 
y  =  np . cos ( 2 * np . pi * x )  *  np . exp ( - x )

plt . plot ( x ,  y ,  'k' ) 
plt . title ( 'Disminución exponencial amortiguada' ,  fontdict = font ) 
plt . text ( 2 ,  0.65 ,  r '$ \ cos (2 \ pi t) \ exp (-t) $' ,  fontdict = font ) 
plt . xlabel ( 'tiempo (s)' ,  fontdict = font ) 
plt . ylabel ( 'voltaje (mV)' , fontdict = font )

# Ajustar el espaciado para evitar el recorte de la etiqueta 
plab . subplots_adjust ( izquierda = 0.15 ) 
plt . show ()
# Out:
#   File "<ipython-input-2-d7df00bc3191>", line 1
#     "" "
#          ^
# SyntaxError: EOL while scanning string literal

# %%
"""
=======================================================
Controlling style of text and labels using a dictionary
=======================================================

This example shows how to share parameters across many text objects and labels
by creating a dictionary of options passed across several functions.
"""

import numpy as np
import matplotlib.pyplot as plt


font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }

x = np.linspace(0.0, 5.0, 100)
y = np.cos(2*np.pi*x) * np.exp(-x)

plt.plot(x, y, 'k')
plt.title('Damped exponential decay', fontdict=font)
plt.text(2, 0.65, r'$\cos(2 \pi t) \exp(-t)$', fontdict=font)
plt.xlabel('time (s)', fontdict=font)
plt.ylabel('voltage (mV)', fontdict=font)

# Tweak spacing to prevent clipping of ylabel
plt.subplots_adjust(left=0.15)
plt.show()

# %%
import numpy as np

a=np.random.random((5,5))
print(a)
# Out:
# [[0.15415461 0.06061011 0.60673278 0.85564831 0.81963475]
#  [0.14258065 0.78605727 0.05911539 0.62224959 0.42690833]
#  [0.22809416 0.99500385 0.33943752 0.2470455  0.72197716]
#  [0.3925554  0.57384896 0.9663315  0.89447118 0.32837431]
#  [0.54182357 0.43934121 0.81343622 0.73065227 0.56848098]]

# %%
minimo=a.min()
maximo=a.max()

minino, maximo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-79422662ce16> in <module>
#       2 maximo=a.max()
#       3
# ----> 4 minino, maximo
#
# NameError: name 'minino' is not defined

# %%
minimo=a.min()
maximo=a.max()

minimo, maximo
# Out:
# (0.05911538602203703, 0.9950038546211374)

# %%
m=(a-minimo)/(maximo-minimo)
m
# Out:
# array([[0.10154973, 0.00159712, 0.58513105, 0.85109813, 0.81261751],
#        [0.08918292, 0.77673987, 0.        , 0.60171081, 0.39298801],
#        [0.18055439, 1.        , 0.29952515, 0.20080396, 0.70827005],
#        [0.35628178, 0.54999456, 0.96936349, 0.89258049, 0.28770407],
#        [0.51577533, 0.40627258, 0.80599437, 0.71753944, 0.54425886]])

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Residencial', 'Comercial', 'Minería', 'Industrial', 'Otros'
sizes = [16, 12, 30, 35, 7]
explode = (0, 0, 0, 0.05, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
savefig(fname, dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None, metadata=None)

# %%
import numpy as np
L=range(1000)
# %timeit [i**2 for i in L]
# Out:
# 1.07 ms ± 128 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
a = np.arange(1000)

# %timeit a**2
# Out:
# 5.71 µs ± 759 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(2, 2)# The matplotlib.pyplot.subplots method provides a way to plot multiple plots on a single figure. 
# Given the number of rows and columns, it returns a tuple (fig, ax), giving a single figure fig with an array of axes ax.
x = np.linspace(0, 8, 1000) # Devuelve números espaciados uniformemente en un intervalo especificado.En este caso: devuelve
# 1000 números entre 0 y 8.

ax[0, 0].plot(x, np.sin(x), 'g') #row=0, col=0
ax[1, 0].plot(x, np.tan(x), 'k') #row=1, col=0
ax[0, 1].plot(range(100), 'b')   #row=0, col=1
ax[1, 1].plot(x, np.cos(x), 'r') #row=1, col=1
fig.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]

# %%
import matplotlib.pyplot as plt
N = 8
y = np.zeros(N) # Vector de N ceros
x1 = np.linspace(0, 10, N, endpoint=True) # vector de N tamaño, formado desde 0 a 10, incluye el 10.
x2 = np.linspace(0, 10, N, endpoint=False) # vector de N tamaño, formado desde 0 a 10, NO incluye el 10.
plt.plot(x1, y, 'o')
plt.plot(x2, y + 0.5, 'o')
plt.ylim([-0.5, 1])
plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Residencial', 'Comercial', 'Minería', 'Industrial', 'Otros'
sizes = [16, 12, 30, 35, 7]
explode = (0, 0, 0, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Minería')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# save the figure
plt.savefig('plot.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
from pylab import *
x = linspace(0, 5, 10)
y = x ** 2
figure()
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('titulo')
show()
